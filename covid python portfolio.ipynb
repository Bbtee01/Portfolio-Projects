# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
import os

# %%
# Reading the data file into the jupyter notebook
df = pd.read_csv('covid.df.csv')

# %%
type (df)

# %%
df
# Out:
#        iso_code continent     location        date  new_cases  new_deaths  \
# 0           AFG      Asia  Afghanistan  24/02/2020        5.0         NaN
# 1           AFG      Asia  Afghanistan  25/02/2020        0.0         NaN
# 2           AFG      Asia  Afghanistan  26/02/2020        0.0         NaN
# 3           AFG      Asia  Afghanistan  27/02/2020        0.0         NaN
# 4           AFG      Asia  Afghanistan  28/02/2020        0.0         NaN
# ...         ...       ...          ...         ...        ...         ...
# 223292      ZWE    Africa     Zimbabwe  08/10/2022        0.0         0.0
# 223293      ZWE    Africa     Zimbabwe  09/10/2022        0.0         0.0
# 223294      ZWE    Africa     Zimbabwe  10/10/2022       94.0         0.0
# 223295      ZWE    Africa     Zimbabwe  11/10/2022        0.0         0.0
# 223296      ZWE    Africa     Zimbabwe  12/10/2022       49.0         0.0
#
#         new_tests
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 223292        NaN
# 223293        NaN
# 223294        NaN
# 223295        NaN
# 223296        NaN
#
# [223297 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223297 entries, 0 to 223296
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   iso_code    223297 non-null  object
#  1   continent   210468 non-null  object
#  2   location    223297 non-null  object
#  3   date        223297 non-null  object
#  4   new_cases   213916 non-null  float64
#  5   new_deaths  194941 non-null  float64
#  6   new_tests   75403 non-null   float64
# dtypes: float64(3), object(4)
# memory usage: 11.9+ MB

# %%
df.describe()
# Out:
#           new_cases     new_deaths     new_tests
# count  2.139160e+05  194941.000000  7.540300e+04
# mean   1.242118e+04     139.781288  6.728541e+04
# std    8.563866e+04     734.308503  2.477340e+05
# min    0.000000e+00       0.000000  1.000000e+00
# 25%    0.000000e+00       0.000000  2.244000e+03
# 50%    5.500000e+01       1.000000  8.783000e+03
# 75%    9.680000e+02      14.000000  3.722900e+04
# max    4.081737e+06   17737.000000  3.585563e+07

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'new_cases', 'new_deaths',
#        'new_tests'],
#       dtype='object')

# %%
df.shape
# Out:
# (223297, 7)

# %%
covid_nigeria = df.query("location == 'Nigeria'")

# %%
covid_nigeria
# Out:
#        iso_code continent location        date  new_cases  new_deaths  \
# 145383      NGA    Africa  Nigeria  28/02/2020        1.0         NaN
# 145384      NGA    Africa  Nigeria  29/02/2020        0.0         NaN
# 145385      NGA    Africa  Nigeria  01/03/2020        0.0         NaN
# 145386      NGA    Africa  Nigeria  02/03/2020        0.0         NaN
# 145387      NGA    Africa  Nigeria  03/03/2020        0.0         NaN
# ...         ...       ...      ...         ...        ...         ...
# 146336      NGA    Africa  Nigeria  08/10/2022       75.0         0.0
# 146337      NGA    Africa  Nigeria  09/10/2022        0.0         0.0
# 146338      NGA    Africa  Nigeria  10/10/2022        0.0         0.0
# 146339      NGA    Africa  Nigeria  11/10/2022        0.0         0.0
# 146340      NGA    Africa  Nigeria  12/10/2022        0.0         0.0
#
#         new_tests
# 145383        NaN
# 145384        NaN
# 145385        NaN
# 145386        NaN
# 145387        NaN
# ...           ...
# 146336        NaN
# 146337        NaN
# 146338        NaN
# 146339        NaN
# 146340        NaN
#
# [958 rows x 7 columns]

# %%
covid_nigeria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 958 entries, 145383 to 146340
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   iso_code    958 non-null    object
#  1   continent   958 non-null    object
#  2   location    958 non-null    object
#  3   date        958 non-null    object
#  4   new_cases   957 non-null    float64
#  5   new_deaths  932 non-null    float64
#  6   new_tests   162 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 59.9+ KB

# %%
covid_nigeria.describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   957.000000  932.000000    162.000000
# mean    277.791014    3.390558   4333.672840
# std     417.831907    6.248681   4359.899415
# min       0.000000    0.000000    504.000000
# 25%      22.000000    0.000000   1950.000000
# 50%     125.000000    1.000000   3023.000000
# 75%     397.000000    5.000000   4429.250000
# max    6158.000000   93.000000  29602.000000

# %%
covid_nigeria.sample(10)
# Out:
#        iso_code continent location        date  new_cases  new_deaths  \
# 145640      NGA    Africa  Nigeria  11/11/2020      180.0         2.0
# 145650      NGA    Africa  Nigeria  21/11/2020      246.0         1.0
# 145704      NGA    Africa  Nigeria  14/01/2021     1479.0        23.0
# 145390      NGA    Africa  Nigeria  06/03/2020        0.0         NaN
# 145591      NGA    Africa  Nigeria  23/09/2020      111.0         2.0
# 146272      NGA    Africa  Nigeria  05/08/2022        0.0         0.0
# 145593      NGA    Africa  Nigeria  25/09/2020      213.0         1.0
# 145679      NGA    Africa  Nigeria  20/12/2020      501.0         3.0
# 146090      NGA    Africa  Nigeria  04/02/2022      135.0         0.0
# 145801      NGA    Africa  Nigeria  21/04/2021       65.0         0.0
#
#         new_tests
# 145640        NaN
# 145650    11088.0
# 145704        NaN
# 145390        NaN
# 145591        NaN
# 146272        NaN
# 145593        NaN
# 145679        NaN
# 146090        NaN
# 145801        NaN

# %%
high_new_cases = covid_nigeria.new_cases > 1000

# %%
covid_nigeria[high_new_cases]
# Out:
#        iso_code continent location        date  new_cases  new_deaths  \
# 145676      NGA    Africa  Nigeria  17/12/2020     1145.0         1.0
# 145682      NGA    Africa  Nigeria  23/12/2020     1133.0         5.0
# 145683      NGA    Africa  Nigeria  24/12/2020     1041.0         6.0
# 145689      NGA    Africa  Nigeria  30/12/2020     1016.0        11.0
# 145690      NGA    Africa  Nigeria  31/12/2020     1031.0        11.0
# 145694      NGA    Africa  Nigeria  04/01/2021     1271.0         7.0
# 145695      NGA    Africa  Nigeria  05/01/2021     1354.0         1.0
# 145696      NGA    Africa  Nigeria  06/01/2021     1664.0         5.0
# 145697      NGA    Africa  Nigeria  07/01/2021     1565.0         6.0
# 145698      NGA    Africa  Nigeria  08/01/2021     1544.0        12.0
# 145699      NGA    Africa  Nigeria  09/01/2021     1585.0         8.0
# 145700      NGA    Africa  Nigeria  10/01/2021     1024.0         8.0
# 145701      NGA    Africa  Nigeria  11/01/2021     1244.0         3.0
# 145702      NGA    Africa  Nigeria  12/01/2021     1270.0        12.0
# 145703      NGA    Africa  Nigeria  13/01/2021     1398.0         9.0
# 145704      NGA    Africa  Nigeria  14/01/2021     1479.0        23.0
# 145705      NGA    Africa  Nigeria  15/01/2021     1867.0         8.0
# 145706      NGA    Africa  Nigeria  16/01/2021     1598.0         7.0
# 145707      NGA    Africa  Nigeria  17/01/2021     1444.0        15.0
# 145708      NGA    Africa  Nigeria  18/01/2021     1617.0        14.0
# 145709      NGA    Africa  Nigeria  19/01/2021     1301.0        15.0
# 145710      NGA    Africa  Nigeria  20/01/2021     1386.0        14.0
# 145711      NGA    Africa  Nigeria  21/01/2021     1964.0         7.0
# 145712      NGA    Africa  Nigeria  22/01/2021     1483.0         5.0
# 145713      NGA    Africa  Nigeria  23/01/2021     2464.0        12.0
# 145715      NGA    Africa  Nigeria  25/01/2021     1430.0         3.0
# 145716      NGA    Africa  Nigeria  26/01/2021     1303.0        15.0
# 145717      NGA    Africa  Nigeria  27/01/2021     1861.0        21.0
# 145719      NGA    Africa  Nigeria  29/01/2021     1650.0        30.0
# 145720      NGA    Africa  Nigeria  30/01/2021     1883.0         1.0
# 145723      NGA    Africa  Nigeria  02/02/2021     1634.0         6.0
# 145724      NGA    Africa  Nigeria  03/02/2021     1138.0         5.0
# 145725      NGA    Africa  Nigeria  04/02/2021     1340.0        14.0
# 145726      NGA    Africa  Nigeria  05/02/2021     1624.0         9.0
# 145727      NGA    Africa  Nigeria  06/02/2021     1588.0         6.0
# 145730      NGA    Africa  Nigeria  09/02/2021     1056.0        21.0
# 145731      NGA    Africa  Nigeria  10/02/2021     1131.0         8.0
# 145733      NGA    Africa  Nigeria  12/02/2021     1005.0        24.0
# 145734      NGA    Africa  Nigeria  13/02/2021     1143.0        13.0
# 145737      NGA    Africa  Nigeria  16/02/2021     1368.0        16.0
# 145738      NGA    Africa  Nigeria  17/02/2021     1073.0        10.0
# 145921      NGA    Africa  Nigeria  19/08/2021     1823.0        15.0
# 145924      NGA    Africa  Nigeria  22/08/2021     1452.0        21.0
# 146034      NGA    Africa  Nigeria  10/12/2021     1287.0         1.0
# 146038      NGA    Africa  Nigeria  14/12/2021     1115.0         2.0
# 146039      NGA    Africa  Nigeria  15/12/2021     1424.0         0.0
# 146040      NGA    Africa  Nigeria  16/12/2021     1051.0         0.0
# 146041      NGA    Africa  Nigeria  17/12/2021     1584.0         1.0
# 146044      NGA    Africa  Nigeria  20/12/2021     1772.0         1.0
# 146046      NGA    Africa  Nigeria  22/12/2021     6158.0         6.0
# 146047      NGA    Africa  Nigeria  23/12/2021     1940.0         0.0
# 146048      NGA    Africa  Nigeria  24/12/2021     1356.0         2.0
# 146049      NGA    Africa  Nigeria  25/12/2021     1305.0        21.0
# 146050      NGA    Africa  Nigeria  26/12/2021     1547.0         8.0
# 146053      NGA    Africa  Nigeria  29/12/2021     1368.0         3.0
# 146054      NGA    Africa  Nigeria  30/12/2021     1126.0         0.0
# 146056      NGA    Africa  Nigeria  01/01/2022     1364.0         3.0
# 146058      NGA    Africa  Nigeria  03/01/2022     1243.0        12.0
#
#         new_tests
# 145676     4747.0
# 145682        NaN
# 145683        NaN
# 145689      890.0
# 145690     9446.0
# 145694     3482.0
# 145695    21135.0
# 145696        NaN
# 145697        NaN
# 145698     6669.0
# 145699     6477.0
# 145700     7499.0
# 145701     8298.0
# 145702        NaN
# 145703        NaN
# 145704        NaN
# 145705     5612.0
# 145706     6376.0
# 145707     6615.0
# 145708    18096.0
# 145709    19632.0
# 145710     6892.0
# 145711     4355.0
# 145712    22066.0
# 145713    16051.0
# 145715    11989.0
# 145716        NaN
# 145717        NaN
# 145719        NaN
# 145720        NaN
# 145723        NaN
# 145724        NaN
# 145725        NaN
# 145726        NaN
# 145727        NaN
# 145730        NaN
# 145731        NaN
# 145733        NaN
# 145734        NaN
# 145737        NaN
# 145738        NaN
# 145921        NaN
# 145924        NaN
# 146034        NaN
# 146038        NaN
# 146039        NaN
# 146040        NaN
# 146041        NaN
# 146044        NaN
# 146046        NaN
# 146047        NaN
# 146048        NaN
# 146049        NaN
# 146050        NaN
# 146053        NaN
# 146054        NaN
# 146056        NaN
# 146058        NaN

# %%
covid_nigeria[high_new_cases].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 145676 to 146058
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   iso_code    58 non-null     object
#  1   continent   58 non-null     object
#  2   location    58 non-null     object
#  3   date        58 non-null     object
#  4   new_cases   58 non-null     float64
#  5   new_deaths  58 non-null     float64
#  6   new_tests   19 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 3.6+ KB

# %%
# total cases and total deaths
total_cases = covid_nigeria.new_cases.sum()
total_deaths = covid_nigeria.new_deaths.sum()

# %%
print ('The number of reported cases is {} and the number of reported deaths is {}.'.format(total_cases,total_deaths))
# Out:
# The number of reported cases is 265846.0 and the number of reported deaths is 3160.0.

# %%
# Overall death rate (ratio of reported deaths to reported cases)
death_rate = covid_nigeria.new_deaths.sum() / covid_nigeria.new_cases.sum()

# %%
print('The overall reported death rate in Nigeria is {:.0%}.'.format(death_rate))
# Out:
# The overall reported death rate in Nigeria is 1%.

# %%
# Overall number of tests conducted
total_tests = covid_nigeria.new_tests.sum()

# %%
total_tests
# Out:
# 702055.0

# %%
# Fraction of tests returned to be positive results
positive_rate = total_cases / total_tests

# %%
print('{:.0%} of tests in Nigeria led to a positive diagnosis.'.format(positive_rate))
# Out:
# 38% of tests in Nigeria led to a positive diagnosis.

# %%
high_ratio_df = covid_nigeria[covid_nigeria.new_cases / covid_nigeria.new_tests > positive_rate]

# %%
high_ratio_df
# Out:
#        iso_code continent location        date  new_cases  new_deaths  \
# 145485      NGA    Africa  Nigeria  09/06/2020      663.0         4.0
# 145491      NGA    Africa  Nigeria  15/06/2020      573.0         4.0
# 145689      NGA    Africa  Nigeria  30/12/2020     1016.0        11.0
# 145711      NGA    Africa  Nigeria  21/01/2021     1964.0         7.0
#
#         new_tests
# 145485     1704.0
# 145491     1399.0
# 145689      890.0
# 145711     4355.0

# %%
# days where highest number of cases where reported
covid_nigeria.sort_values('new_cases', ascending=False).head(10)
# Out:
#        iso_code continent location        date  new_cases  new_deaths  \
# 146046      NGA    Africa  Nigeria  22/12/2021     6158.0         6.0
# 145713      NGA    Africa  Nigeria  23/01/2021     2464.0        12.0
# 145711      NGA    Africa  Nigeria  21/01/2021     1964.0         7.0
# 146047      NGA    Africa  Nigeria  23/12/2021     1940.0         0.0
# 145720      NGA    Africa  Nigeria  30/01/2021     1883.0         1.0
# 145705      NGA    Africa  Nigeria  15/01/2021     1867.0         8.0
# 145717      NGA    Africa  Nigeria  27/01/2021     1861.0        21.0
# 145921      NGA    Africa  Nigeria  19/08/2021     1823.0        15.0
# 146044      NGA    Africa  Nigeria  20/12/2021     1772.0         1.0
# 145696      NGA    Africa  Nigeria  06/01/2021     1664.0         5.0
#
#         new_tests
# 146046        NaN
# 145713    16051.0
# 145711     4355.0
# 146047        NaN
# 145720        NaN
# 145705     5612.0
# 145717        NaN
# 145921        NaN
# 146044        NaN
# 145696        NaN

# %% [markdown]
# ##### Seems like the reported cases on 12th Dec was very high compared to the rest and also the number of cases where at the peak at the beginning of the year 2021

# %%
# days where highest number of deaths where recorded
covid_nigeria.sort_values('new_deaths', ascending=False).head(10)
# Out:
#        iso_code continent location        date  new_cases  new_deaths  \
# 145931      NGA    Africa  Nigeria  29/08/2021      362.0        93.0
# 145930      NGA    Africa  Nigeria  28/08/2021      650.0        53.0
# 145979      NGA    Africa  Nigeria  16/10/2021      376.0        35.0
# 145980      NGA    Africa  Nigeria  17/10/2021      125.0        33.0
# 145492      NGA    Africa  Nigeria  16/06/2020      490.0        31.0
# 145938      NGA    Africa  Nigeria  05/09/2021      459.0        30.0
# 145719      NGA    Africa  Nigeria  29/01/2021     1650.0        30.0
# 145841      NGA    Africa  Nigeria  31/05/2021      203.0        28.0
# 145937      NGA    Africa  Nigeria  04/09/2021      964.0        27.0
# 145987      NGA    Africa  Nigeria  24/10/2021      165.0        26.0
#
#         new_tests
# 145931        NaN
# 145930        NaN
# 145979        NaN
# 145980        NaN
# 145492     2079.0
# 145938        NaN
# 145719        NaN
# 145841        NaN
# 145937        NaN
# 145987        NaN

# %%
covid_nigeria.date = pd.to_datetime(covid_nigeria.date)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6936\332833113.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   covid_nigeria.date = pd.to_datetime(covid_nigeria.date)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6936\332833113.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_nigeria.date = pd.to_datetime(covid_nigeria.date)

# %%
covid_nigeria['year'] = pd.DatetimeIndex(covid_nigeria.date).year
covid_nigeria['month'] = pd.DatetimeIndex(covid_nigeria.date).month
covid_nigeria['weekday'] = pd.DatetimeIndex(covid_nigeria.date).weekday
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6936\3215074592.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_nigeria['year'] = pd.DatetimeIndex(covid_nigeria.date).year
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6936\3215074592.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_nigeria['month'] = pd.DatetimeIndex(covid_nigeria.date).month
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6936\3215074592.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_nigeria['weekday'] = pd.DatetimeIndex(covid_nigeria.date).weekday

# %%
covid_nigeria['month_full'] = covid_nigeria['date'].dt.month_name()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6936\444885531.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_nigeria['month_full'] = covid_nigeria['date'].dt.month_name()

# %%
covid_nigeria
# Out:
#        iso_code continent location       date  new_cases  new_deaths  \
# 145383      NGA    Africa  Nigeria 2020-02-28        1.0         NaN
# 145384      NGA    Africa  Nigeria 2020-02-29        0.0         NaN
# 145385      NGA    Africa  Nigeria 2020-01-03        0.0         NaN
# 145386      NGA    Africa  Nigeria 2020-02-03        0.0         NaN
# 145387      NGA    Africa  Nigeria 2020-03-03        0.0         NaN
# ...         ...       ...      ...        ...        ...         ...
# 146336      NGA    Africa  Nigeria 2022-08-10       75.0         0.0
# 146337      NGA    Africa  Nigeria 2022-09-10        0.0         0.0
# 146338      NGA    Africa  Nigeria 2022-10-10        0.0         0.0
# 146339      NGA    Africa  Nigeria 2022-11-10        0.0         0.0
# 146340      NGA    Africa  Nigeria 2022-12-10        0.0         0.0
#
#         new_tests  year  month  weekday month_full
# 145383        NaN  2020      2        4   February
# 145384        NaN  2020      2        5   February
# 145385        NaN  2020      1        4    January
# 145386        NaN  2020      2        0   February
# 145387        NaN  2020      3        1      March
# ...           ...   ...    ...      ...        ...
# 146336        NaN  2022      8        2     August
# 146337        NaN  2022      9        5  September
# 146338        NaN  2022     10        0    October
# 146339        NaN  2022     11        3   November
# 146340        NaN  2022     12        5   December
#
# [958 rows x 11 columns]

# %%
monthly_groups= covid_nigeria.groupby('month')

# %%
# sum of new cases,deaths, and tests in each months of the year
monthly_groups[['new_cases','new_deaths','new_tests']].sum()
# Out:
#        new_cases  new_deaths  new_tests
# month
# 1        40233.0       367.0   141283.0
# 2        18837.0       272.0     6507.0
# 3        10924.0       176.0    13467.0
# 4        11382.0       166.0    38704.0
# 5        14887.0       282.0    61602.0
# 6        20369.0       267.0    37793.0
# 7        26199.0       278.0    87248.0
# 8        27956.0       418.0    96082.0
# 9        19208.0       255.0    39500.0
# 10       14903.0       287.0    73202.0
# 11       13553.0       123.0    43841.0
# 12       47395.0       269.0    62826.0

# %%
weekly_groups =covid_nigeria.groupby('weekday')

# %%
# sum of new cases,deaths, and tests in each days of the week
weekly_groups[['new_cases','new_deaths','new_tests']].mean()
# Out:
#           new_cases  new_deaths    new_tests
# weekday
# 0        239.308824    3.142857  3929.192308
# 1        295.955882    3.181818  3908.869565
# 2        329.074074    3.141791  5578.608696
# 3        300.890511    3.270677  3195.173913
# 4        271.210145    3.234848  5032.619048
# 5        279.572464    3.850746  5102.304348
# 6        229.160584    3.902985  3702.478261

# %%
covid_nigeria['total_cases'] = (covid_nigeria.new_cases).cumsum()
covid_nigeria['total_deaths'] = (covid_nigeria.new_deaths).cumsum()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6936\3883692056.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_nigeria['total_cases'] = (covid_nigeria.new_cases).cumsum()
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6936\3883692056.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_nigeria['total_deaths'] = (covid_nigeria.new_deaths).cumsum()

# %%
covid_nigeria.set_index('date', inplace=True)

# %%
covid_nigeria
# Out:
#            iso_code continent location  new_cases  new_deaths  new_tests  \
# date
# 2020-02-28      NGA    Africa  Nigeria        1.0         NaN        NaN
# 2020-02-29      NGA    Africa  Nigeria        0.0         NaN        NaN
# 2020-01-03      NGA    Africa  Nigeria        0.0         NaN        NaN
# 2020-02-03      NGA    Africa  Nigeria        0.0         NaN        NaN
# 2020-03-03      NGA    Africa  Nigeria        0.0         NaN        NaN
# ...             ...       ...      ...        ...         ...        ...
# 2022-08-10      NGA    Africa  Nigeria       75.0         0.0        NaN
# 2022-09-10      NGA    Africa  Nigeria        0.0         0.0        NaN
# 2022-10-10      NGA    Africa  Nigeria        0.0         0.0        NaN
# 2022-11-10      NGA    Africa  Nigeria        0.0         0.0        NaN
# 2022-12-10      NGA    Africa  Nigeria        0.0         0.0        NaN
#
#             year  month  weekday month_full  total_cases  total_deaths
# date
# 2020-02-28  2020      2        4   February          1.0           NaN
# 2020-02-29  2020      2        5   February          1.0           NaN
# 2020-01-03  2020      1        4    January          1.0           NaN
# 2020-02-03  2020      2        0   February          1.0           NaN
# 2020-03-03  2020      3        1      March          1.0           NaN
# ...          ...    ...      ...        ...          ...           ...
# 2022-08-10  2022      8        2     August     265846.0        3160.0
# 2022-09-10  2022      9        5  September     265846.0        3160.0
# 2022-10-10  2022     10        0    October     265846.0        3160.0
# 2022-11-10  2022     11        3   November     265846.0        3160.0
# 2022-12-10  2022     12        5   December     265846.0        3160.0
#
# [958 rows x 12 columns]

# %%
covid_nigeria.groupby('year').new_cases.sum().plot.bar();

# %%
covid_nigeria.groupby('month').new_cases.sum().plot.line();
